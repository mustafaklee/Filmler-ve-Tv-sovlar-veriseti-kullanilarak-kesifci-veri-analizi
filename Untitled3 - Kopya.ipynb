# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\musta\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\musta\anaconda3\lib\site-packages (from seaborn) (1.26.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\musta\anaconda3\lib\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\musta\anaconda3\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\musta\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\musta\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\musta\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\musta\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\musta\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\musta\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\musta\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\musta\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\musta\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\musta\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\musta\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\musta\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\musta\anaconda3\lib\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\musta\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\musta\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\musta\anaconda3\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\musta\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("TMDB_tv_dataset_v3.csv")
df2=df #dil sayımında kullanilacak

# %%
print(df.isnull().values.any())  #eksik deger var mı?
# Out:
# True

# %%
print(df.isnull().sum()) #eksik değerler kaç tane var?
# Out:
# id                           0
# name                         5
# number_of_seasons            0
# number_of_episodes           0
# original_language            0
# vote_count                   0
# vote_average                 0
# overview                 73834
# adult                        0
# backdrop_path            89285
# first_air_date           31478
# last_air_date            29646
# homepage                115768
# in_production                0
# original_name                5
# popularity                   0
# poster_path              59099
# type                         0
# status                       0
# tagline                 161074
# genres                   67628
# created_by              130225
# languages                57415
# networks                 69546
# origin_country           31025
# spoken_languages         58174
# production_companies    107630
# production_countries     89679
# episode_run_time             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
print(df.isnull().sum())  #hiç eksik değerimiz kalmadı...
# Out:
# id                      0
# name                    0
# number_of_seasons       0
# number_of_episodes      0
# original_language       0
# vote_count              0
# vote_average            0
# overview                0
# adult                   0
# backdrop_path           0
# first_air_date          0
# last_air_date           0
# homepage                0
# in_production           0
# original_name           0
# popularity              0
# poster_path             0
# type                    0
# status                  0
# tagline                 0
# genres                  0
# created_by              0
# languages               0
# networks                0
# origin_country          0
# spoken_languages        0
# production_companies    0
# production_countries    0
# episode_run_time        0
# dtype: int64

# %%
df=df[(df.number_of_seasons>0) & (df.number_of_episodes>0) & (df.episode_run_time>4) & (df.vote_count>500)]   #aykırı değerleri sildik

# %% [raw]
# ilk 20 popüler film
# hangi dilden kaç film var
# en çok konuşulan diller
# popüler filmlerin konuşma dilleri
# en çok üretilen ülke
# bölüm süresinin konuşulan  dille ilgisi

# %%
en_populer=df.sort_values("vote_average",ascending=False).head(20)   #azalan sıralama;en yüksek oylu filmleri belirledik

# %%
en_populer
# Out:
#          id                                name  number_of_seasons  \
# 21    60625                      Rick and Morty                  7
# 51    70785                      Anne with an E                  3
# 77      246          Avatar: The Last Airbender                  3
# 375  124834                        Heartstopper                  3
# 120   67915                              Goblin                  1
# 266   92685                       The Owl House                  3
# 190   31132                        Regular Show                  8
# 568   68349     Weightlifting Fairy Kim Bok-joo                  1
# 239   97186                        Love, Victor                  3
# 780   94796                Crash Landing on You                  1
# 32     1408                               House                  8
# 488   89901                           Dickinson                  3
# 325   96462            It's Okay to Not Be Okay                  1
# 615   79732  She-Ra and the Princesses of Power                  5
# 157   61222                     BoJack Horseman                  6
# 18    60574                      Peaky Blinders                  6
# 312   61617                Over the Garden Wall                  1
# 44    19885                            Sherlock                  4
# 176    1438                            The Wire                  5
# 121   40075                       Gravity Falls                  2
#
#      number_of_episodes original_language  vote_count  vote_average  \
# 21                   71                en        8595         8.700
# 51                   27                en        4383         8.696
# 77                   61                en        3497         8.690
# 375                  17                en        1044         8.670
# 21                Science makes sense, family doesn't.
# 51                       Welcome back to Green Gables.
# 77                            Water. Earth. Fire. Air.
# 375  The beginning of one thing can be the rest of ...
# 120  A mysterious romance between a goblin and a yo...
# 266                 Us weirdos have to stick together.
# 190                                 It's anything but.
# 568                                 Do you like Messi?
# 239                  One last chance to feel the love.
# 780  Sometimes the wrong train takes you to the rig...
# 32                            Genius has side effects.
# 488                         Hope is worth every fight.
# 325   When you can't control yourself, count to three.
# 615                                  A hero will rise.
# 157        Don't look back. You're not going that way.
# 18                             London's for the taking
# 312                              Will you take a peek?
# 44                  A new sleuth for the 21st century.
# 176                                   All in the game.
# 121                                Just west of weird.
#
#                                                 genres  \
# 21   Animation, Comedy, Sci-Fi & Fantasy, Action & ...
# 51                                       Drama, Family
# 77     Animation, Action & Adventure, Sci-Fi & Fantasy
# 375                                              Drama
# 120                    Drama, Sci-Fi & Fantasy, Comedy
# 266  Animation, Sci-Fi & Fantasy, Drama, Action & A...
# 190                                  Animation, Comedy
# 568                                      Comedy, Drama
# 239                                      Comedy, Drama
# 780                      Drama, Comedy, War & Politics
# 32                                      Drama, Mystery
# 488                                      Comedy, Drama
# 325                                      Drama, Comedy
# 615                  Animation, Kids, Sci-Fi & Fantasy
# 157                           Animation, Comedy, Drama
# 18                                        Drama, Crime
# 312  Mystery, Sci-Fi & Fantasy, Animation, Family, ...
# 44                               Crime, Drama, Mystery
# 176                                       Crime, Drama
# 121  Animation, Comedy, Mystery, Sci-Fi & Fantasy, ...
#
#                                     created_by       languages  \
# 21                  Dan Harmon, Justin Roiland              en
# 51                        Moira Walley-Beckett              en
# 77    Michael Dante DiMartino, Bryan Konietzko              en
# 375                               Alice Oseman              en
# 120                 Kim Eun-sook, Lee Eung-bok              ko
# 266                               Dana Terrace      en, da, es
# 190                               J.G. Quintel              en
# 568  Yang Hee-seung, Oh Hyun-jong, Kim Soo-jin              ko
# 239            Isaac Aptaker, Elizabeth Berger              en
# 780                  Park Ji-eun, Lee Jung-hyo          en, ko
# 32                                 David Shore              en
# 488                                Alena Smith              en
# 325                     Park Shin-woo, Jo Yong              ko
# 615                               ND Stevenson              en
# 157                       Raphael Bob-Waksberg              en
# 18                               Steven Knight              en
# 312                             Patrick McHale              en
# 44                  Mark Gatiss, Steven Moffat              en
# 176                                David Simon  es, en, el, zh
# 121                                Alex Hirsch              en
#
#                       networks  origin_country  \
# 21                  Adult Swim              US
# 51              CBC Television              CA
# 77                 Nickelodeon              US
# 375                    Netflix              GB
# 120                        tvN              KR
# 266             Disney Channel              US
# 190            Cartoon Network              US
# 568                        MBC              KR
# 239              Hulu, Disney+              US
# 780               Netflix, tvN              KR
# 32                         FOX              US
# 488                  Apple TV+              US
# 325                        tvN              KR
# 615                    Netflix              US
# 157                    Netflix              US
# 18            BBC One, BBC Two              GB
# 312            Cartoon Network              US
# 44                     BBC One              GB
# 176                        HBO              US
# 121  Disney Channel, Disney XD              US
#
#                     spoken_languages  \
# 21                           English
# 51                           English
# 77                           English
# 375                          English
# 120                          한국어/조선말
# 266          English, Dansk, Español
# 190                          English
# 568                          한국어/조선말
# 239                          English
# 780                 English, 한국어/조선말
# 32                           English
# 488                          English
# 325                          한국어/조선말
# 615                          English
# 157                          English
# 18                           English
# 312                          English
# 44                           English
# 176  Español, English, ελληνικά, 普通话
# 121                          English
#
#                                   production_companies  \
# 21   Williams Street, Harmonious Claptrap, Justin R...
# 51         Northwood Entertainment, Northwood Pictures
# 77   Nickelodeon Animation Studio, JM Animation, DR...
# 375                                      See-Saw Films
# 120                    Hwa&Dam Pictures, Studio Dragon
# 266     Disney Television Animation, Rough Draft Korea
# 190                            Cartoon Network Studios
# 568                                   Chorokbaem Media
# 239  20th Century Fox Television, Temple Hill Enter...
# 780                       Studio Dragon, Culture Depot
# 32   Universal Television, Bad Hat Harry Production...
# 488  wiip, Anonymous Content, Sugar23, Tuning Fork ...
# 325                                      Studio Dragon
# 615                    DreamWorks Animation Television
# 157   Tornante Company, ShadowMachine, Boxer vs Raptor
# 18   Tiger Aspect, BBC Studios, Caryn Mandabach Pro...
# 312   Warner Bros. Television, Cartoon Network Studios
# 44             Hartswood Films, BBC Wales, Masterpiece
# 176  Blown Deadline Productions, Anthony Hemingway ...
# 121                        Disney Television Animation
#
#                          production_countries episode_run_time
# 21                   United States of America               22
# 51                                     Canada               47
# 77      South Korea, United States of America               25
# 375                            United Kingdom               30
# 120                               South Korea               77
# 266                  United States of America               22
# 190                  United States of America               11
# 568                               South Korea               60
# 239                  United States of America               30
# 780        South Korea, Mongolia, Switzerland               85
# 32                   United States of America               44
# 488                  United States of America               30
# 325                               South Korea               75
# 615                  United States of America               24
# 157                  United States of America               25
# 18                             United Kingdom               58
# 312                  United States of America               11
# 44   United Kingdom, United States of America               90
# 176                  United States of America               60
# 121                  United States of America               22
#
# [20 rows x 29 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5)) #büyüklük
sns.barplot(x=en_populer.vote_average, y=en_populer.name) #x ve y eksenine hangi veriler gelecek
plt.xticks(rotation= 0)   #yazının derecesi 45 çapraz 90 dik
plt.xlabel('Puan')
plt.ylabel('Sovlar')
plt.title('En iyi Sovlar')
plt.show()

# %%
sns.boxplot(x=en_populer.number_of_seasons); #En iyi 20 şovun sezon sayilari
plt.title('En iyi 20 sovun kaç sezon oldugu');

# %%
o_lang = df2.original_language.value_counts().head(6)

# %%
o_lang={'language':o_lang.index , 'count':o_lang.values}

# %%
pd.DataFrame(o_lang)
# Out:
#   language  count
# 0       en   1470
# 1       ko    176
# 2       pt     71
# 3       ja     37
# 4       hi     31
# 5       fr     27

# %%
plt.figure(figsize=(10,5)) #büyüklük
sns.barplot(x=o_lang["language"], y=o_lang["count"]) #x ve y eksenine hangi veriler gelecek
plt.xticks(rotation= 90)   #yazının derecesi 45 çapraz 90 dik
plt.xlabel('Dil')
plt.ylabel('Sayi')
plt.title('En çok kullanılan orijinal diller')
plt.show()

# %%
#Ülkelere göre bölüm süreleri

# %%
plt.figure(figsize=(10,5)) #büyüklük
sns.barplot(x=df.production_countries, y=df.episode_run_time);#x ve y eksenine hangi veriler gelecek
plt.xticks(rotation= 90)   #yazının derecesi 45 çapraz 90 dik
plt.xlabel('Ülke')
plt.ylabel('Ortalama Bölüm Süreleri')
plt.title('Ülkelere göre bölüm süreleri')
plt.show();
